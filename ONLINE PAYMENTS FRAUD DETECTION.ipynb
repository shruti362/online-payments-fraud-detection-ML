# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report, confusion_matrix
import warnings
import pickle

# %%
df=pd.read_csv(r'C:\Users\tejas\Downloads\archive\PS_20174392719_1491204439457_log.csv')

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df.drop(['isFlaggedFraud'], axis=1, inplace=True)

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
# [6362620 rows x 10 columns]

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0  M1979787155             0.0             0.0        0
# 1  M2044282225             0.0             0.0        0
# 2   C553264065             0.0             0.0        1
# 3    C38997010         21182.0             0.0        1
# 4  M1230701703             0.0             0.0        0

# %%
df.tail()
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud
# 6362615             0.0   C776919290            0.00       339682.13        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1

# %%
plt.style.use('ggplot')
warnings.filterwarnings('ignore')

# %%
df.corr(numeric_only=True)
# Out:
#                     step    amount  oldbalanceOrg  newbalanceOrig  \
# step            1.000000  0.022373      -0.010058       -0.010299
# amount          0.022373  1.000000      -0.002762       -0.007861
# oldbalanceOrg  -0.010058 -0.002762       1.000000        0.998803
# newbalanceOrig -0.010299 -0.007861       0.998803        1.000000
# oldbalanceDest  0.027665  0.294137       0.066243        0.067812
# newbalanceDest  0.025888  0.459304       0.042029        0.041837
# isFraud         0.031578  0.076688       0.010154       -0.008148
#
#                 oldbalanceDest  newbalanceDest   isFraud
# step                  0.027665        0.025888  0.031578
# amount                0.294137        0.459304  0.076688
# oldbalanceOrg         0.066243        0.042029  0.010154
# newbalanceOrig        0.067812        0.041837 -0.008148
# oldbalanceDest        1.000000        0.976569 -0.005885
# newbalanceDest        0.976569        1.000000  0.000535
# isFraud              -0.005885        0.000535  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
#step
sns.histplot(data=df, x='step')
# Out:
# <Axes: xlabel='step', ylabel='Count'>

# %%
sns.boxplot(data=df, x='step')
# Out:
# <Axes: xlabel='step'>

# %%
#type
sns.countplot(data=df, x='type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
#amount
sns.histplot(data=df, x='amount')
# Out:
# <Axes: xlabel='amount', ylabel='Count'>

# %%
sns.boxplot(data=df, x='amount')
# Out:
# <Axes: xlabel='amount'>

# %%
sns.histplot(data=df, x='oldbalanceOrg')
# Out:
# <Axes: xlabel='oldbalanceOrg', ylabel='Count'>

# %%
#nameDest
df['nameDest'].value_counts()
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
#               ...
# C1049862186      1
# C2118381511      1
# C2099952089      1
# C1027984317      1
# C1251365829      1
# Name: count, Length: 2722362, dtype: int64

# %%
#oldbalanceDest
sns.boxplot(data=df, x='oldbalanceDest')
# Out:
# <Axes: xlabel='oldbalanceDest'>

# %%
sns.boxplot(data=df, x='newbalanceDest')
# Out:
# <Axes: xlabel='newbalanceDest'>

# %%
#isFraud:
sns.countplot(data=df, x='isFraud')
# Out:
# <Axes: xlabel='isFraud', ylabel='count'>

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df.loc[df['isFraud'] == 0, 'isFraud'] = 'is not Fraud'
df.loc[df['isFraud'] == 1, 'isFraud'] = 'is Fraud'

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  \
# 0             160296.36  M1979787155            0.00            0.00
# 1              19384.72  M2044282225            0.00            0.00
# 2                  0.00   C553264065            0.00            0.00
# 3                  0.00    C38997010        21182.00            0.00
# 4              29885.86  M1230701703            0.00            0.00
# ...                 ...          ...             ...             ...
# 6362615            0.00   C776919290            0.00       339682.13
# 6362616            0.00  C1881841831            0.00            0.00
# 6362617            0.00  C1365125890        68488.84      6379898.11
# 6362618            0.00  C2080388513            0.00            0.00
# 6362619            0.00   C873221189      6510099.11      7360101.63
#
#               isFraud
# 0        is not Fraud
# 1        is not Fraud
# 2            is Fraud
# 3            is Fraud
# 4        is not Fraud
# ...               ...
# 6362615      is Fraud
# 6362616      is Fraud
# 6362617      is Fraud
# 6362618      is Fraud
# 6362619      is Fraud
#
# [6362620 rows x 10 columns]

# %%
sns.jointplot(data=df, x='newbalanceDest', y='isFraud')

# %%
sns.countplot(data=df, x='type', hue='isFraud')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.boxplot(data=df, x='isFraud', y='step')
# Out:
# <Axes: xlabel='isFraud', ylabel='step'>

# %%
sns.boxplot(data=df, x='isFraud', y='amount')
# Out:
# <Axes: xlabel='isFraud', ylabel='amount'>

# %%
sns.boxplot(data=df, x='isFraud', y='oldbalanceOrg')
# Out:
# <Axes: xlabel='isFraud', ylabel='oldbalanceOrg'>

# %%
sns.boxplot(data=df, x='isFraud', y='newbalanceOrig')
# Out:
# <Axes: xlabel='isFraud', ylabel='newbalanceOrig'>

# %%
sns.violinplot(data=df, x='isFraud', y='oldbalanceDest')
# Out:
# <Axes: xlabel='isFraud', ylabel='oldbalanceDest'>

# %%
sns.violinplot(data=df, x='isFraud', y='newbalanceDest')
# Out:
# <Axes: xlabel='isFraud', ylabel='newbalanceDest'>

# %%
df.describe(include='all')
# Out:
#                 step      type        amount     nameOrig  oldbalanceOrg  \
# count   6.362620e+06   6362620  6.362620e+06      6362620   6.362620e+06
# unique           NaN         5           NaN      6353307            NaN
# top              NaN  CASH_OUT           NaN  C1677795071            NaN
# freq             NaN   2237500           NaN            3            NaN
# mean    2.433972e+02       NaN  1.798619e+05          NaN   8.338831e+05
# std     1.423320e+02       NaN  6.038582e+05          NaN   2.888243e+06
# min     1.000000e+00       NaN  0.000000e+00          NaN   0.000000e+00
# 25%     1.560000e+02       NaN  1.338957e+04          NaN   0.000000e+00
# 50%     2.390000e+02       NaN  7.487194e+04          NaN   1.420800e+04
# 75%     3.350000e+02       NaN  2.087215e+05          NaN   1.073152e+05
# max     7.430000e+02       NaN  9.244552e+07          NaN   5.958504e+07
#
#         newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  \
# count     6.362620e+06      6362620    6.362620e+06    6.362620e+06
# unique             NaN      2722362             NaN             NaN
# top                NaN  C1286084959             NaN             NaN
# freq               NaN          113             NaN             NaN
# mean      8.551137e+05          NaN    1.100702e+06    1.224996e+06
# std       2.924049e+06          NaN    3.399180e+06    3.674129e+06
# min       0.000000e+00          NaN    0.000000e+00    0.000000e+00
# 25%       0.000000e+00          NaN    0.000000e+00    0.000000e+00
# 50%       0.000000e+00          NaN    1.327057e+05    2.146614e+05
# 75%       1.442584e+05          NaN    9.430367e+05    1.111909e+06
# max       4.958504e+07          NaN    3.560159e+08    3.561793e+08
#
#              isFraud
# count        6362620
# unique             2
# top     is not Fraud
# freq         6354407
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %%
df.shape
# Out:
# (6362620, 10)

# %%
df.drop(['nameOrig', 'nameDest'], axis=1, inplace=True)
df.columns
# Out:
# Index(['step', 'type', 'amount', 'oldbalanceOrg', 'newbalanceOrig',
#        'oldbalanceDest', 'newbalanceDest', 'isFraud'],
#       dtype='object')

# %%
df.head()
# Out:
#    step      type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1     1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2     1  TRANSFER    181.00          181.0            0.00             0.0
# 3     1  CASH_OUT    181.00          181.0            0.00         21182.0
# 4     1   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest       isFraud
# 0             0.0  is not Fraud
# 1             0.0  is not Fraud
# 2             0.0      is Fraud
# 3             0.0      is Fraud
# 4             0.0  is not Fraud

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# oldbalanceOrg     0
# newbalanceOrig    0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   oldbalanceOrg   float64
#  4   newbalanceOrig  float64
#  5   oldbalanceDest  float64
#  6   newbalanceDest  float64
#  7   isFraud         object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 388.3+ MB

# %%
sns.boxplot(df['amount'])
# Out:
# <Axes: ylabel='amount'>

# %%
from scipy import stats

print(stats.mode(df['amount']))
print(np.mean(df['amount']))
# Out:
# ModeResult(mode=np.float64(10000000.0), count=np.int64(3207))
# 179861.90354913071

# %%
q1 = np.quantile(df['amount'], 0.25)
q3 = np.quantile(df['amount'], 0.75)

IQR = q3 - q1

upper_bound = q3 + (1.5 * IQR)
lower_bound = q1 - (1.5 * IQR)

print('q1 :', q1)
print('q3 :', q3)
print('IQR :', IQR)
print('Upper Bound :', upper_bound)
print('Lower Bound :', lower_bound)

print('Skewed data :', len(df[df['amount'] > upper_bound]))
print('Skewed data :', len(df[df['amount'] < lower_bound]))
# Out:
# q1 : 13389.57
# q3 : 208721.4775
# IQR : 195331.9075
# Upper Bound : 501719.33875
# Lower Bound : -279608.29125
# Skewed data : 338078
# Skewed data : 0

# %%
# To handle outliers transformation techniques are used.

def transformationPlot(feature):
    plt.figure(figsize=(12,5))
    
    plt.subplot(1,2,1)
    sns.distplot(feature)
    
    plt.subplot(1,2,2)
    stats.probplot(feature, plot=plt)

# %%
transformationPlot(np.log(df['amount'] + 1))

# %%
df['amount'] = np.log(df['amount'] + 1)

# %%
import numpy as np
df['amount'] = np.log1p(df['amount'])

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['type'] = le.fit_transform(df['type'])

# %%
x = df.drop('isFraud', axis=1)
y = df['isFraud']

# %%
y.isnull().sum()
# Out:
# np.int64(0)

# %%
x
# Out:
#          step  type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0           1     3  2.321826      170136.00       160296.36            0.00
# 1           1     3  2.143726       21249.00        19384.72            0.00
# 2           1     4  1.825195         181.00            0.00            0.00
# 3           1     1  1.825195         181.00            0.00        21182.00
# 4           1     3  2.338406       41554.00        29885.86            0.00
# ...       ...   ...       ...            ...             ...             ...
# 6362615   743     1  2.620003      339682.13            0.00            0.00
# 6362616   743     4  2.812883     6311409.28            0.00            0.00
# 6362617   743     1  2.812883     6311409.28            0.00        68488.84
# 6362618   743     4  2.684645      850002.52            0.00            0.00
# 6362619   743     1  2.684645      850002.52            0.00      6510099.11
#
#          newbalanceDest
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00
# ...                 ...
# 6362615       339682.13
# 6362616            0.00
# 6362617      6379898.11
# 6362618            0.00
# 6362619      7360101.63
#
# [6362620 rows x 7 columns]

# %%
y
# Out:
# 0          is not Fraud
# 1          is not Fraud
# 2              is Fraud
# 3              is Fraud
# 4          is not Fraud
#                ...
# 6362615        is Fraud
# 6362616        is Fraud
# 6362617        is Fraud
# 6362618        is Fraud
# 6362619        is Fraud
# Name: isFraud, Length: 6362620, dtype: object

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (5090096, 7)
# (1272524, 7)
# (1272524,)
# (5090096,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(
    n_estimators=10,     # fewer trees → faster
    max_depth=8,         # avoid overfitting
    random_state=42
)

rfc.fit(x_train, y_train)

y_test_predict1 = rfc.predict(x_test)
test_accuracy = accuracy_score(y_test, y_test_predict1)

print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 0.9996322269756799

# %%
y_train_predict1 = rfc.predict(x_train)
train_accuracy = accuracy_score(y_train, y_train_predict1)
train_accuracy
# Out:
# 0.9996328163555265

# %%
import pandas as pd

pd.crosstab(y_test, y_test_predict1)
# Out:
# col_0         is Fraud  is not Fraud
# isFraud
# is Fraud          1160           460
# is not Fraud         8       1270896

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_test_predict1))
# Out:
#               precision    recall  f1-score   support
#
#     is Fraud       0.99      0.72      0.83      1620
# is not Fraud       1.00      1.00      1.00   1270904
#
#     accuracy                           1.00   1272524
#    macro avg       1.00      0.86      0.92   1272524
# weighted avg       1.00      1.00      1.00   1272524

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)

y_test_predict2 = dtc.predict(x_test)
test_accuracy = accuracy_score(y_test, y_test_predict2)
test_accuracy
# Out:
# 0.9997241702317599

# %%
y_train_predict2 = dtc.predict(x_train)
train_accuracy = accuracy_score(y_train, y_train_predict2)
train_accuracy
# Out:
# 1.0

# %%
import pandas as pd

pd.crosstab(y_test, y_test_predict2)
# Out:
# col_0         is Fraud  is not Fraud
# isFraud
# is Fraud          1423           197
# is not Fraud       154       1270750

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_test_predict2))
# Out:
#               precision    recall  f1-score   support
#
#     is Fraud       0.90      0.88      0.89      1620
# is not Fraud       1.00      1.00      1.00   1270904
#
#     accuracy                           1.00   1272524
#    macro avg       0.95      0.94      0.95   1272524
# weighted avg       1.00      1.00      1.00   1272524

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score

etc = ExtraTreesClassifier()
etc.fit(x_train, y_train)

y_test_predict3 = etc.predict(x_test)
test_accuracy = accuracy_score(y_test, y_test_predict3)
test_accuracy
# Out:
# 0.9997060959164621

# %%
y_train_predict3 = etc.predict(x_train)
train_accuracy = accuracy_score(y_train, y_train_predict3)
train_accuracy
# Out:
# 1.0

# %%
import pandas as pd

pd.crosstab(y_test, y_test_predict3)
# Out:
# col_0         is Fraud  is not Fraud
# isFraud
# is Fraud          1257           363
# is not Fraud        11       1270893

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_test_predict3))
# Out:
#               precision    recall  f1-score   support
#
#     is Fraud       0.99      0.78      0.87      1620
# is not Fraud       1.00      1.00      1.00   1270904
#
#     accuracy                           1.00   1272524
#    macro avg       1.00      0.89      0.94   1272524
# weighted avg       1.00      1.00      1.00   1272524

# %%
from sklearn.svm import LinearSVC

svc = LinearSVC()
svc.fit(x_train, y_train)
# Out:
# LinearSVC()

# %%
y_test_predict4 = svc.predict(x_test)
test_accuracy = accuracy_score(y_test, y_test_predict4)
test_accuracy
# Out:
# 0.9959026313059715

# %%
y_train_predict4 = svc.predict(x_train)
train_accuracy = accuracy_score(y_train, y_train_predict4)
train_accuracy
# Out:
# 0.995784951796587

# %%
import pandas as pd

pd.crosstab(y_test, y_test_predict4)
# Out:
# col_0         is Fraud  is not Fraud
# isFraud
# is Fraud           593          1027
# is not Fraud      4187       1266717

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_test_predict4))
# Out:
#               precision    recall  f1-score   support
#
#     is Fraud       0.12      0.37      0.19      1620
# is not Fraud       1.00      1.00      1.00   1270904
#
#     accuracy                           1.00   1272524
#    macro avg       0.56      0.68      0.59   1272524
# weighted avg       1.00      1.00      1.00   1272524

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'oldbalanceOrg', 'newbalanceOrig',
#        'oldbalanceDest', 'newbalanceDest', 'isFraud'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

la = LabelEncoder()
y_train1 = la.fit_transform(y_train)

# %%
y_test1 = la.transform(y_test)

# %%
y_test1 = la.transform(y_test)

# %%
y_test1
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(1272524,))

# %%
y_train1
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(5090096,))

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score

xgb1 = xgb.XGBClassifier()
xgb1.fit(x_train, y_train1)

y_test_predict5 = xgb1.predict(x_test)
test_accuracy = accuracy_score(y_test1, y_test_predict5)
test_accuracy
# Out:
# 0.9995795757093776

# %%
y_train_predict5 = xgb1.predict(x_train)
train_accuracy = accuracy_score(y_train1, y_train_predict5)
train_accuracy
# Out:
# 0.9995976500246754

# %%
import pandas as pd

pd.crosstab(y_test1, y_test_predict5)
# Out:
# col_0     0        1
# row_0
# 0      1266      354
# 1       181  1270723

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test1, y_test_predict5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.78      0.83      1620
#            1       1.00      1.00      1.00   1270904
#
#     accuracy                           1.00   1272524
#    macro avg       0.94      0.89      0.91   1272524
# weighted avg       1.00      1.00      1.00   1272524

# %%
def compareModel():
    print("train accuracy for rfc", accuracy_score(y_train_predict1, y_train))
    print("test accuracy for rfc", accuracy_score(y_test_predict1, y_test))
    
    print("train accuracy for dtc", accuracy_score(y_train_predict2, y_train))
    print("test accuracy for dtc", accuracy_score(y_test_predict2, y_test))
    
    print("train accuracy for etc", accuracy_score(y_train_predict3, y_train))
    print("test accuracy for etc", accuracy_score(y_test_predict3, y_test))
    
    print("train accuracy for svc", accuracy_score(y_train_predict4, y_train))
    print("test accuracy for svc", accuracy_score(y_test_predict4, y_test))
    
    print("train accuracy for xgb1", accuracy_score(y_train_predict5, y_train1))
    print("test accuracy for xgb1", accuracy_score(y_test_predict5, y_test1))

# %%
compareModel()
# Out:
# train accuracy for rfc 0.9996328163555265
# test accuracy for rfc 0.9996322269756799
# train accuracy for dtc 1.0
# test accuracy for dtc 0.9997241702317599
# train accuracy for etc 1.0
# test accuracy for etc 0.9997060959164621
# train accuracy for svc 0.995784951796587
# test accuracy for svc 0.9959026313059715
# train accuracy for xgb1 0.9995976500246754
# test accuracy for xgb1 0.9995795757093776

# %%
import pickle
pickle.dump(dtc, open('payments.pkl', 'wb'))
